# %% [markdown]
# # How to define Personalized driver models
#
# - **Personalized driver models** are learned from the data collected from the specific driver. For instance, the personalized model of driver \#1 is learned using the driving data collected from driver \#1.
# - **Average driver models** are learned using the data collected from other nine drivers.

# %%
# Driving style 
# PCA
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
# %matplotlib inline

TIME_VARIANTS = [3]
def get_data(driver_i):
    pickle_name = 'pickle/driver_data_' + str(TIME_VARIANTS[0]) + '.pkl'
    with open(pickle_name, "rb") as f:
        DATA = pickle.load(f)
    
    dynamic_drv = DATA[driver_i]['dynamic_drv']
    surr_zone = DATA[driver_i]['surr_zones']
    driver_id = DATA[driver_i]['driver_id']
    
    o = dynamic_drv.drop("velocity", axis=1) # observed information
    v = dynamic_drv.velocity # hidden variable: velocity
    x_columns = dynamic_drv.columns
        
    return driver_id, dynamic_drv, surr_zone, o, v, x_columns

# %%
import itertools

from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture
from sklearn.model_selection import train_test_split

def driver_model_vae():
    plt.figure(figsize=(15, 10))
    for i in range(10):
        driver_id, dynamic_drv, surr_zone, o, velocity, x_columns = get_data(i)
        
        
driver_model_vae()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-145-b2a2f8a9a23a> in <module>
#      59     plt.savefig('bic/bic_k_tight.png')
#      60
# ---> 61 driver_model_gmm()
#      62
#
# <ipython-input-145-b2a2f8a9a23a> in driver_model_gmm()
#      57         plt.tight_layout()
#      58
# ---> 59     plt.savefig('bic/bic_k_tight.png')
#      60
#      61 driver_model_gmm()
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     840 def savefig(*args, **kwargs):
#     841     fig = gcf()
# --> 842     res = fig.savefig(*args, **kwargs)
#     843     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     844     return res
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1589         pil_kwargs.setdefault("format", format)
#    1590         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1591         image.save(fname, **pil_kwargs)
#    1592
#    1593
#
# ~/.pyenv/versions/3.7.8/envs/carla_env/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2153                 fp = builtins.open(filename, "r+b")
#    2154             else:
# -> 2155                 fp = builtins.open(filename, "w+b")
#    2156
#    2157         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bic/bic_k_tight.png'

# %% [markdown]
# #### 3. Simulation
# - Lane change scenarios

# %%
gmm5= [14.646659083823453, 15.404403797825733, 9.653483429250576, 11.229009796558874, 12.126119618255698, 8.806966396290479, 13.012201020973853, 17.698201643430664, 14.019224156260467, 9.598311021815361]

# %% [markdown]
# #### 4. Personalized data driven control
# 1. Personalized MPC
# 2. Risk adaptive control
# 3. Data-driven control
#   - Training phase
#   - Inference phase

# %% [markdown]
# #### 5.Experimental result
# - KL divergence
# - MSE
# - Interrupting time
# - Subjective risk evaluation

# %%
gmm5 = [14.646659083823453, 15.404403797825733, 9.653483429250576, 11.229009796558874, 12.126119618255698, 8.806966396290479, 13.012201020973853, 17.698201643430664, 14.019224156260467, 9.598311021815361]
gmm7 = [14.77711253651537, 15.7606110071174, 9.809528691839157, 11.46399618763712, 11.68914429257308, 9.239177267709803, 12.848740596815745, 17.4794343270186, 13.873162997168574, 9.622553383435008]
gmm9 = [10.626325216259287, 8.081849482607474, 7.473894650810207, 8.582976622193318, 8.504851372525048, 5.9205303252312, 9.111075841851997, 8.228119700514371, 10.395547048863449, 7.045034790832809]
vae = [29.36996928423071, 45.94260680401793, 18.151828348841043, 21.670330131313293, 24.63292380938292, 19.010422420574777, 26.430226019813077, 51.83459378005133, 26.402662944260065, 17.74712687875769]
cvae= [10.545253694096584, 8.167437699236263, 7.746229849459656, 8.748753531369287, 8.508049546648605, 5.879570445573125, 9.055804601200654, 8.169513593660735, 10.369184959433651, 7.010516066724594]


data = [gmm5,gmm7,gmm9,vae,cvae]
plt.figure(figsize=(12,8))
sns.barplot(data=data)
plt.ylabel('MAE of velocity prediction [km/h]')
plt.rcParams["font.size"] = 18
plt.ylim([0,45])
plt.xticks([])
print(plt.xticks())
plt.savefig('velocity_comparison.png')
# Out:
# (array([], dtype=float64), [])
